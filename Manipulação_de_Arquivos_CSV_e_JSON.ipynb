# %% [markdown]
# <a href="https://colab.research.google.com/github/lucian-bonifacio/Projeto-001---Fundamentos/blob/main/Manipula%C3%A7%C3%A3o_de_Arquivos_CSV_e_JSON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Importar bibliotecas

# %%
import pandas as pd

# %%
csv_exemplo = pd.read_csv('/content/drive/MyDrive/MACHINE LEARNING/ChatGPT/001 - Manipulação de Arquivos CSV e JSON/csv_dados.csv')
csv_exemplo
# Out:
#       Nome  Idade          Cidade
# 0      Ana     25       São Paulo
# 1    Bruno     30  Rio de Janeiro
# 2   Carlos     22  Belo Horizonte
# 3  Daniela     28        Curitiba

# %%
csv_exemplo.head()
# Out:
#       Nome  Idade          Cidade
# 0      Ana     25       São Paulo
# 1    Bruno     30  Rio de Janeiro
# 2   Carlos     22  Belo Horizonte
# 3  Daniela     28        Curitiba

# %%
json_exemplo = pd.read_json('/content/drive/MyDrive/MACHINE LEARNING/ChatGPT/001 - Manipulação de Arquivos CSV e JSON/json_dados.json')
json_exemplo
# Out:
#                                              pessoas
# 0  {'Nome': 'Ana', 'Idade': 25, 'Cidade': 'São Pa...
# 1  {'Nome': 'Bruno', 'Idade': 30, 'Cidade': 'Rio ...
# 2  {'Nome': 'Carlos', 'Idade': 22, 'Cidade': 'Bel...
# 3  {'Nome': 'Daniela', 'Idade': 28, 'Cidade': 'Cu...

# %%
json_exemplo_normalizado = pd.json_normalize(json_exemplo['pessoas'])
json_exemplo_normalizado
# Out:
#       Nome  Idade          Cidade
# 0      Ana     25       São Paulo
# 1    Bruno     30  Rio de Janeiro
# 2   Carlos     22  Belo Horizonte
# 3  Daniela     28        Curitiba

# %%
csv_exemplo.to_excel('/content/drive/MyDrive/MACHINE LEARNING/ChatGPT/001 - Manipulação de Arquivos CSV e JSON/csv_excel.xlsx')
